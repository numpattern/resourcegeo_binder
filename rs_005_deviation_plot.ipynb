# %% [markdown]
# **Deviations around a reference after a sensitivity analysis**

# %%
import resourcegeo as rs
import random
import numpy as np
n, ref = 15, 30
a = np.linspace(1,n+1,n)
s = np.random.normal(0, 0.5, n)
b = [ref+j for j in s]
rs.plots.deviation.deviation_plot(a,b,ref)
